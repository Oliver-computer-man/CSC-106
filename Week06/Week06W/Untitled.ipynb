# %%
n = 1

while n <= 5:
    print(n)
    n = n + 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
inp = int(input("Prompt:"))

if (inp > 92 and inp <= 100):
    print('A')
    
else if(inp > 90 and inp <= 91):
        print('A-')
# Out:
#   Cell In[12], line 6
#     else if(inp > 90 and inp <= 91)
#          ^
# SyntaxError: expected ':'

# %%
print("hi")
