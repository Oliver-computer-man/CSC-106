# %% [markdown]
# Make a four way trafick light with pedestrians and left terns.
#     -light can move on light green
#         *EW_light
#         *NS_light
#     -pedestrians can move on light Red
#         *EW_pedestrians
#         *NS_pedestrians
#     -left turns cars can turn on RED or GREEN?
#         *Cars can turn left
#         *pedestians can not go dering left set
