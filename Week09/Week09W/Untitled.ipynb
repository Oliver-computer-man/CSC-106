# %%
array = [2, 1]

for i in array:
    print(i)
    
    if(array[i]>array[i+1])
        array[i],array[i+1]=array[i+1],array[i]
# Out:
#   Cell In[3], line 6
#     if(array[i]>array[i+1])
#                            ^
# SyntaxError: expected ':'
