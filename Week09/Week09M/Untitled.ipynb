# %%
def customer_greetimgs(Hotels):
    for x in Hotels:
        print("hello " + x)
        
customers = ["Michelle", "Kim", "Miguel"]

# %%
customer_greetimgs(customers)
# Out:
# hello Michelle
# hello Kim
# hello Miguel

# %%
from datetime import datetime
now = datetime.now()
current_time = now.strftime("%H:%M:%S:")
print("Current Time =", current_time)
# Out:
# Current Time = 09:40:00:

# %%
print(help(math)
# Out:
#   Cell In[2], line 1
#     print(help(math)
#                     ^
# SyntaxError: incomplete input
