# %%
#!/usr/bin/env python
# coding: utf-8

# # Escape Sequence Characters

# # Examples

In[1]: print("\n\nHallo")

In[2]:print("\tHallo")

In[3]:print("                          Hallo")
# Out:
# Hallo
# 	Hallo
#                           Hallo

# %% [markdown]
# # # Question
# Using '*' (star) and Escape Sequence Characters create the shape 'M' in University of Mary.
# End of quiz
# # In[ ]:

# %%
In[1]:print("**/\/\")
# Out:
#   Cell In[2], line 1
#     In[1]:print("**/\/\")
#                 ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
In[1]:print("**/\/\**")
# Out:
# **/\/\**
# <>:1: SyntaxWarning: invalid escape sequence '\/'
# <>:1: SyntaxWarning: invalid escape sequence '\/'
# /tmp/ipykernel_7185/1000936644.py:1: SyntaxWarning: invalid escape sequence '\/'
#   In[1]:print("**/\/\**")

# %%
print("\*m")
# Out:
# \*m
# <>:1: SyntaxWarning: invalid escape sequence '\*'
# <>:1: SyntaxWarning: invalid escape sequence '\*'
# /tmp/ipykernel_7185/4256912184.py:1: SyntaxWarning: invalid escape sequence '\*'
#   print("\*m")

# %%
print("*     *")
print("*  *  *")
print("*     *")
print("*     *")
# Out:
# *     *
# *  *  *
# *     *
# *     *

# %%
print("*       *" + "\n**     **" + "\n    *    " + "\n*       *" + "\n\n*       *")
# Out:
# *       *
# **     **
#     *
# *       *
#
# *       *
