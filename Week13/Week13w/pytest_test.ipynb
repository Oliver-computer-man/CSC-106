# %%
#Testing adichun
def test_corect1():
    assert (1+1) == 2
def test_wrong1():
    assert (1+1) == 3
    
#Testing subtraction
def test_corect2():
    assert (1-3) == -2
def test_wrong2():
    assert (1-1) == 3
   
#Testing Multiplication
def test_corect3():
    assert (1*2) == 2
def test_wrong3():
    assert (1*1) == 3
    
#Testing divition
def test_corect4():
    assert (2/1) == 2
def test_wrong4():
    assert (1/1) == 3
