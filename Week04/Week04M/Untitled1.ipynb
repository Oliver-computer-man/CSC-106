# %%
import cmath

a = float(input("Enter a: "))
b = float(input("Enter b: "))
c = float(input("Enter c: "))

disc = (b**2) - (4*a*b)
x1 = (-b-(disc))/2*a
x2 = (-b+(disc))/2*a

print(x1, x2)
# Out:
# Enter a: 1
# Enter b: 2
# Enter c: -35
# 1.0 -3.0
