# %%
List1 = [1, 2, 3, 4]

# %%
print (List1)
# Out:
# [1, 2, 3, 4]

# %%
 L1 = [1, 2, 1.2 , "A", True]

# %%
type(L1)
# Out:
# list

# %%
L1[4]=False

# %%
print(L1)
# Out:
# [1, 2, 1.2, 'A', False]

# %%
L1[4:4]=[True]
print(L1)
# Out:
# [1, 2, 1.2, 'A', True, False]

# %%
Dict1 = {
    "Name": "Jesus",
    "birth" : "12/25/0",
    "addres": "Juruselum"
    }

# %%
print(Dict1)
# Out:
# {'Name': 'Jesus', 'birth': '12/25/0', 'addres': 'Juruselum'}

# %%
TinT = (1, 2, (8, 9), "A", True)

# %%
print(TinT[2])
# Out:
# (8, 9)
