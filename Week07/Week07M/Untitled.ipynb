# %% [markdown]
# Q1 : What is wrong with this code? Explain. (4 marks)

# %%
i = 1
while i < 6:
  print(i)
  i += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# Q2 : Fill in the blank. (3 marks)

# %%
fruits = ["apple", "banana", "cherry"]
for x in fruits:
  if x == "banana":
    break
  print(x)
# Out:
# apple

# %% [markdown]
# Q3 : What is the output? (3 marks)

# %%
#output is nothing due to thare being in the if statement the a and b are swicht.
a = 33
b = 200
if b < a:
  print("b is greater than a")

# %%
#the proper way to say that b is grater.
a = 33
b = 200
if b > a:
  print("b is greater than a")
# Out:
# b is greater than a
